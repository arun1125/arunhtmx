# %%
import pandas as pd
import numpy as np
import scipy as sp

# %% [markdown]
# # This is a reduced implementation of the following paper
# - https://arxiv.org/pdf/2302.06018.pdf

# %% [markdown]
# # Context
#
# Why am I even implementing this paper?
# (great question)
#
# 1. We are currently building out some tech at work to do RTB (not too sure how much im allowed to discuss here)
# 2. Part of the tech includes building out a RTB platform.
# 3. A key feature of a RTB platform is
#
# ![image.png](attachment:image.png)
